# %%
import pandas as pd

# %%
customer_demographic = pd.read_excel("KPMG_VI_New_raw_data_update_final.xlsx", header=1 ,sheet_name = 3)

# %%
customer_demographic.head()
# Out:
#    customer_id      first_name  last_name  gender  \
# 0            1         Laraine  Medendorp       F
# 1            2             Eli    Bockman    Male
# 2            3           Arlin     Dearle    Male
# 3            4          Talbot        NaN    Male
# 4            5  Sheila-kathryn     Calton  Female
#
#    past_3_years_bike_related_purchases        DOB               job_title  \
# 0                                   93 1953-10-12     Executive Secretary
# 1                                   81 1980-12-16  Administrative Officer
# 2                                   61 1954-01-20      Recruiting Manager
# 3                                   33 1961-10-03                     NaN
# 4                                   56 1977-05-13           Senior Editor
#
#   job_industry_category     wealth_segment deceased_indicator  \
# 0                Health      Mass Customer                  N
# 1    Financial Services      Mass Customer                  N
# ...

# %%
customer_demographic.isnull().sum()[customer_demographic.isnull().sum()>0]
# Out:
# last_name                125
# DOB                       87
# job_title                506
# job_industry_category    656
# default                  302
# tenure                    87
# dtype: int64

# %%
customer_demographic.dtypes
# Out:
# customer_id                                     int64
# first_name                                     object
# last_name                                      object
# gender                                         object
# past_3_years_bike_related_purchases             int64
# DOB                                    datetime64[ns]
# job_title                                      object
# job_industry_category                          object
# wealth_segment                                 object
# deceased_indicator                             object
# default                                        object
# owns_car                                       object
# tenure                                        float64
# dtype: object

# %%
customer_demographic.gender.value_counts()
# Out:
# Female    2037
# Male      1872
# U           88
# F            1
# Femal        1
# M            1
# Name: gender, dtype: int64

# %%
customer_demographic['gender'].replace(['M','F','Femal'],['Male','Female','Female'],inplace = True)

# %%
customer_demographic.gender.value_counts()
# Out:
# Female    2039
# Male      1873
# U           88
# Name: gender, dtype: int64

# %%
customer_demographic.dropna(subset = ['DOB','job_industry_category','job_title'], inplace =True)

# %%
customer_demographic.isnull().sum()[customer_demographic.isnull().sum()>0]
# Out:
# last_name     85
# default      155
# dtype: int64

# %%
customer_demographic.sort_values(by = ['DOB'], ascending = True)
# Out:
#       customer_id first_name    last_name  gender  \
# 33             34   Jephthah     Bachmann       U
# 719           720     Darrel        Canet    Male
# 1091         1092     Katlin      Creddon  Female
# 2412         2413      Abbey       Murrow    Male
# 657           658       Donn      Bonnell    Male
# ...           ...        ...          ...     ...
# 3948         3949      Costa  Sleightholm    Male
# 469           470     Darbee    Klimowicz    Male
# 2295         2296   Nathalia       Sanger  Female
# 1887         1888      Sibyl      Scholtz  Female
# 65             66     Anselm        Gawne    Male
#
#       past_3_years_bike_related_purchases        DOB  \
# 33                                     59 1843-12-21
# 719                                    67 1931-10-23
# 1091                                   56 1935-08-22
# 2412                                   27 1943-08-11
# 657                                    38 1944-01-24
# ...

# %%
customer_demographic.drop(index = 33, inplace =True)

# %%
customer_demographic['Age'] = 2020 - customer_demographic.DOB.dt.year

# %%
customer_demographic.wealth_segment.value_counts()
# Out:
# Mass Customer        1427
# High Net Worth        734
# Affluent Customer     703
# Name: wealth_segment, dtype: int64

# %%
customer_demographic = customer_demographic[customer_demographic['deceased_indicator']=='N']

# %%
customer_demographic.isnull().sum()
# Out:
# customer_id                              0
# first_name                               0
# last_name                               85
# gender                                   0
# past_3_years_bike_related_purchases      0
# DOB                                      0
# job_title                                0
# job_industry_category                    0
# wealth_segment                           0
# deceased_indicator                       0
# default                                154
# owns_car                                 0
# tenure                                   0
# Age                                      0
# dtype: int64

# %%
customer_demographic.drop(columns = ['default'], axis = 1, inplace = True)

# %%
customer_demographic.head()
# Out:
#    customer_id first_name  last_name  gender  \
# 0            1    Laraine  Medendorp  Female
# 1            2        Eli    Bockman    Male
# 2            3      Arlin     Dearle    Male
# 8            9       Mala       Lind  Female
# 9           10   Fiorenze    Birdall  Female
#
#    past_3_years_bike_related_purchases        DOB  \
# 0                                   93 1953-10-12
# 1                                   81 1980-12-16
# 2                                   61 1954-01-20
# 8                                   97 1973-03-10
# 9                                   49 1988-10-11
#
#                               job_title job_industry_category  \
# 0                   Executive Secretary                Health
# 1                Administrative Officer    Financial Services
# 2                    Recruiting Manager              Property
# 8  Business Systems Development Analyst           Argiculture
# 9               Senior Quality Engineer    Financial Services
#
# ...
