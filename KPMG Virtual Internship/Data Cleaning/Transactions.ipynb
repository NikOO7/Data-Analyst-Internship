# %%
import pandas as pd

# %%
transactions = pd.read_excel("KPMG_VI_New_raw_data_update_final.xlsx", header=1 ,sheet_name = 1)

# %%
transactions.head()
# Out:
#    transaction_id  product_id  customer_id transaction_date  online_order  \
# 0               1           2         2950       2017-02-25           0.0
# 1               2           3         3120       2017-05-21           1.0
# 2               3          37          402       2017-10-16           0.0
# 3               4          88         3135       2017-08-31           0.0
# 4               5          78          787       2017-10-01           1.0
#
#   order_status           brand product_line product_class product_size  \
# 0     Approved           Solex     Standard        medium       medium
# 1     Approved   Trek Bicycles     Standard        medium        large
# 2     Approved      OHM Cycles     Standard           low       medium
# 3     Approved  Norco Bicycles     Standard        medium       medium
# 4     Approved  Giant Bicycles     Standard        medium        large
#
#    list_price  standard_cost product_first_sold_date
# ...

# %%
transactions.dtypes
# Out:
# transaction_id                      int64
# product_id                          int64
# customer_id                         int64
# transaction_date           datetime64[ns]
# online_order                      float64
# order_status                       object
# brand                              object
# product_line                       object
# product_class                      object
# product_size                       object
# list_price                        float64
# standard_cost                     float64
# product_first_sold_date    datetime64[ns]
# dtype: object

# %%
transactions.isnull().sum()
# Out:
# transaction_id               0
# product_id                   0
# customer_id                  0
# transaction_date             0
# online_order               360
# order_status                 0
# brand                      197
# product_line               197
# product_class              197
# product_size               197
# list_price                   0
# standard_cost              197
# product_first_sold_date    197
# dtype: int64

# %%
transactions.sort_values(by = ['transaction_date'])
# Out:
#        transaction_id  product_id  customer_id transaction_date  online_order  \
# 516               517          77          311       2017-01-01           1.0
# 5876             5877          67          138       2017-01-01           0.0
# 3459             3460          64          234       2017-01-01           1.0
# 12484           12485          85         2805       2017-01-01           1.0
# 19130           19131           0         1707       2017-01-01           0.0
# ...               ...         ...          ...              ...           ...
# 605               606          70         2878       2017-12-30           0.0
# 15269           15270           3          195       2017-12-30           0.0
# 19906           19907          41         1721       2017-12-30           0.0
# 15756           15757          30         3130       2017-12-30           0.0
# 12003           12004          21         3283       2017-12-30           NaN
#
# ...

# %%
transactions.online_order.value_counts()
# Out:
# 1.0    9829
# 0.0    9811
# Name: online_order, dtype: int64

# %%
transactions.order_status.value_counts()
# Out:
# Approved     19821
# Cancelled      179
# Name: order_status, dtype: int64

# %%
transactions.dropna(subset = ['online_order','brand'],inplace = True)

# %%
transactions.list_price.describe()
# Out:
# count    19445.000000
# mean      1107.337193
# std        582.662400
# min         12.010000
# 25%        575.270000
# 50%       1163.890000
# 75%       1635.300000
# max       2091.470000
# Name: list_price, dtype: float64

# %%
transactions['profit'] = transactions['list_price'] - transactions['standard_cost']
