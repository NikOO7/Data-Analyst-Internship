# %%
import import_ipynb

# %%
from Customer_Demographic import customer_demographic
# Out:
# importing Jupyter notebook from Customer_Demographic.ipynb

# %%
from Transactions import transactions
# Out:
# importing Jupyter notebook from Transactions.ipynb

# %%
from Customer_Address import customer_address
# Out:
# importing Jupyter notebook from Customer_Address.ipynb

# %%
import pandas as pd

# %%
new_customer_list = pd.read_excel("KPMG_VI_New_raw_data_update_final.xlsx", header=1 ,sheet_name = 2)

# %%
new_customer_list.head()
# Out:
#   first_name  last_name  gender  past_3_years_bike_related_purchases  \
# 0    Chickie    Brister    Male                                   86
# 1      Morly     Genery    Male                                   69
# 2    Ardelis  Forrester  Female                                   10
# 3     Lucine      Stutt  Female                                   64
# 4    Melinda     Hadlee  Female                                   34
#
#          DOB                   job_title job_industry_category  \
# 0 1957-07-12             General Manager         Manufacturing
# 1 1970-03-22         Structural Engineer              Property
# 2 1974-08-28      Senior Cost Accountant    Financial Services
# 3 1979-01-28  Account Representative III         Manufacturing
# 4 1965-09-21           Financial Analyst    Financial Services
#
#       wealth_segment deceased_indicator owns_car  ...  state    country  \
# 0      Mass Customer                  N      Yes  ...    QLD  Australia
# ...

# %%
new_customer_list.dtypes
# Out:
# first_name                                     object
# last_name                                      object
# gender                                         object
# past_3_years_bike_related_purchases             int64
# DOB                                    datetime64[ns]
# job_title                                      object
# job_industry_category                          object
# wealth_segment                                 object
# deceased_indicator                             object
# owns_car                                       object
# tenure                                          int64
# address                                        object
# postcode                                        int64
# state                                          object
# country                                        object
# property_valuation                              int64
# Unnamed: 16                                   float64
# ...

# %%
new_customer_list.isnull().sum()
# Out:
# first_name                               0
# last_name                               29
# gender                                   0
# past_3_years_bike_related_purchases      0
# DOB                                     17
# job_title                              106
# job_industry_category                  165
# wealth_segment                           0
# deceased_indicator                       0
# owns_car                                 0
# tenure                                   0
# address                                  0
# postcode                                 0
# state                                    0
# country                                  0
# property_valuation                       0
# Unnamed: 16                              0
# Unnamed: 17                              0
# Unnamed: 18                              0
# Unnamed: 19                              0
# Unnamed: 20                              0
# Rank                                     0
# ...

# %%
new_customer_list.sort_values(by= ['DOB'])
# Out:
#     first_name   last_name  gender  past_3_years_bike_related_purchases  \
# 797    Anthony     Morison    Male                                    7
# 885  Zachariah  Meininking    Male                                   40
# 769     Andrea      Pendle  Female                                   86
# 585    Letizia       Poore  Female                                   27
# 265     Alleen       Eaken  Female                                   56
# ..         ...         ...     ...                                  ...
# 775     Dmitri       Viant       U                                   62
# 835      Porty      Hansed       U                                   88
# 883      Shara    Bramhill       U                                   24
# 904       Roth        Crum       U                                    0
# 984    Pauline    Dallosso       U                                   82
#
#            DOB                   job_title job_industry_category  \
# ...

# %%
new_customer_list.dropna(subset = ['DOB','job_title','job_industry_category'],inplace = True)

# %%
new_customer_list.gender.value_counts()
# Out:
# Female    380
# Male      355
# Name: gender, dtype: int64

# %%
new_customer_list.drop(columns = ['Unnamed: 20'],axis = 1,inplace =True)

# %%
cd C:\Users\kalpa\KPMG Virtua Intern
# Out:
# C:\Users\kalpa\KPMG Virtua Intern

# %%
datatoexcel = pd.ExcelWriter("KPMG_module_1.xlsx")

# %%
customer_demographic.to_excel(datatoexcel, sheet_name = 'customer_demographic',index = False)

# %%
transactions.to_excel(datatoexcel, sheet_name = 'transactions', index = False)

# %%
customer_address.to_excel(datatoexcel, sheet_name = 'customer_address', index = False)

# %%
new_customer_list.to_excel(datatoexcel, sheet_name = 'new_customer_list', index = False)

# %%
datatoexcel.close()
