# %%
import import_ipynb

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
from Customer_Demographic import customer_demographic
# Out:
# importing Jupyter notebook from Customer_Demographic.ipynb

# %%
from New_customer_list import new_customer_list
# Out:
# importing Jupyter notebook from New_customer_list.ipynb

# %%
from Customer_Address import customer_address
# Out:
# importing Jupyter notebook from Customer_Address.ipynb

# %%
import pandas as pd

# %%
sns.catplot(x="Age_Cat", kind="count", palette="ch:.25", data=customer_demographic)
plt.title('Old Customer Age Distribution')
plt.xlabel('Customer Age')
# Out:
# Text(0.5, 6.79999999999999, 'Customer Age')

# %%
sns.catplot(x="Age_Cat", kind="count", palette="ch:.25", data=new_customer_list)
plt.title('New Customer Age Distribution')
plt.xlabel('Customer Age')
# Out:
# Text(0.5, 6.79999999999999, 'Customer Age')

# %%
customer_demographic_new = customer_demographic[['gender', 'past_3_years_bike_related_purchases']]

# %%
new = customer_demographic_new.groupby('gender').past_3_years_bike_related_purchases.agg(['sum'])

# %%
total = 98359+93483+3718
new = pd.DataFrame({'Gender':['Female','Male','U'],'Sum':[98359/total,93483/total,3718/total]})

# %%
new
# Out:
#    Gender       Sum
# 0  Female  0.502961
# 1    Male  0.478027
# 2       U  0.019012

# %%
sns.catplot(y="Sum",x= 'Gender',kind = 'bar', palette="ch:.25", data=new)
plt.ylabel('Bike related purchases in past 3 years (%)')
plt.title('Bike related purchases Vs. Gender')
plt.savefig("figure5.png")

# %%
new_customer_list.job_industry_category.value_counts()
# Out:
# Financial Services    187
# Manufacturing         175
# Health                138
# Retail                 73
# Property               51
# Entertainment          34
# IT                     30
# Argiculture            24
# Telecommunications     23
# Name: job_industry_category, dtype: int64

# %%
plt.figure(figsize = (10,6))
my_data = [187,175,138,73,51,34,30,24,23]
my_labels = ['Financial Services','Manufacturing','Health','Retail','Property','Entertainment','IT','Argiculture','Telecommunications']
my_colors = ['lightblue','lightsteelblue','silver']
explode = list()
for k in my_labels:
    explode.append(0.1)
plt.pie(my_data, labels=my_labels, explode=explode, shadow=True,autopct='%1.1f%%')
plt.title('New Customer Job Industry Distribution')
# Out:
# Text(0.5, 1.0, 'New Customer Job Industry Distribution')

# %%
customer_demographic.job_industry_category.value_counts()
# Out:
# Manufacturing         695
# Financial Services    682
# Health                542
# Retail                304
# Property              231
# IT                    126
# Entertainment         122
# Argiculture            99
# Telecommunications     61
# Name: job_industry_category, dtype: int64

# %%
plt.figure(figsize = (10,6))
my_data = [695,682,542,304,231,126,122,99,61]
my_labels = ['Manufacturing','Financial Services','Health','Retail','Property','IT','Entertainment','Argiculture','Telecommunications']
my_colors = ['lightblue','lightsteelblue','silver']
explode = list()
for k in my_labels:
    explode.append(0.1)
plt.pie(my_data, labels=my_labels, explode=explode, shadow=True,autopct='%1.1f%%')
plt.savefig("figure6.png")
plt.title('Old Customer Job Industry Distribution')
# Out:
# Text(0.5, 1.0, 'Old Customer Job Industry Distribution')

# %%
sns.catplot(x="Age_Cat", hue="wealth_segment", kind="count",palette="ch:.25", data=new_customer_list)
plt.ylabel("Number of people in Age Category")
plt.xlabel('Age Category')
plt.title("New Customer Wealth Segment by Age")
# Out:
# Text(0.5, 1.0, 'New Customer Wealth Segment by Age')

# %%
sns.catplot(x="Age_Cat", hue="wealth_segment", kind="count",palette="ch:.25", data=customer_demographic)
plt.ylabel("Number of people in Age Category")
plt.xlabel('Age Category')
plt.title("Old Customer Wealth Segment by Age")
# Out:
# Text(0.5, 1.0, 'Old Customer Wealth Segment by Age')

# %%
owns_car_new = pd.merge(customer_address, customer_demographic )

# %%
owns_car_new = owns_car_new[['state','owns_car']]

# %%
owns_car_new.head()
# Out:
#   state owns_car
# 0   NSW      Yes
# 1   NSW      Yes
# 2   NSW      Yes
# 3   QLD       No
# 4   VIC      Yes

# %%
sns.catplot(x="state", hue="owns_car", kind="count",palette="ch:.25", data=owns_car_new)
plt.title("Number of cars owned in each state")
# Out:
# Text(0.5, 1.0, 'Number of cars owned in each state')
